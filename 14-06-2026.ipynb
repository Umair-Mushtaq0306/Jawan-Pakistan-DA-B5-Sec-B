# %%
dir[list]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 dir[list]
#
# TypeError: 'builtin_function_or_method' object is not subscriptable

# %%
salaries = ["20k","40k","50K","150k"]

# %%
salaries.append("100k")

# %%
salaries

# %%
salaries.insert(3,"120")

# %%
salaries

# %%
salaries[2] = "70k"

# %%
salaries

# %%
salaries[2:5]

# %%
salaries[2:5] = "35k","45k","55k"

# %%
salaries

# %%
salaries1 = ['20k', '45k', '90k', '45k', '100k', '200k', '40k', '35k', '70k']
print(salaries1)
salaries1.append("200K")
salaries1.extend(["150","9000"])
print(salaries1)
salaries1.insert(2,"S")
print(salaries1)
print(salaries1[:5])
salaries1 = ["1","2","3","4","5"]
print(salaries1[:5])
print(len(salaries1))

# %%
salaries[2] = "60k","85k"

# %%
salaries

# %%
salaries.pop()

# %%
salaries

# %%
salaries.pop(2)

# %%
salaries

# %%
salaries.remove("40k")

# %%
salaries

# %%
salaries.extend(["110k","135k","180k"])

# %%
salaries

# %%
dir(list)

# %%
salaries.sort()

# %%
salaries

# %%
salaries.count("100k")

# %%
salaries.clear()

# %%
salaries

# %%
salaries = ["110k","135k","100K","20k","45k"]

# %%
salaries

# %%
Copy_salaries = salaries.copy()

# %%
salaries.extend(Copy_salaries)

# %%
salaries

# %%
salaries.reverse()

# %%
salaries

# %%
Num = [10,20,30]

# %%
Num.insert(1,15)

# %%
Num

# %%
Color = ["yellow","red","Black","White","Blue"]

# %%
Color.remove("Black")

# %%
Color

# %%
Fruit = ["banana","apple","mango"]

# %%
Fruit.remove("apple")

# %%
Fruit

# %%
List_As = [5,2,9,1,7]

# %%
List_As.sort()

# %%
List_As

# %%
Fruit1 = ["apple","mango","banana"]

# %%
Fruit1.index("mango")

# %%
Num.sort(reverse=True)

# %%
Num

# %%
dir(str)

# %%
upper = "we are learning python"

# %%
upper.lower

# %%
message = "python is fun prog"

# %%
print(message.find("fun"))

# %%
message.index("is")

# %%
message.count("p")

# %%
'abc124'.isalnum()

# %%
'anc'.isalpha()

# %%
'anc12'.isalpha()

# %%
message.split()

# %%
# Define the string
text = "we are learning python"

# Convert to uppercase
upper_text = text.upper()

# Print the result
print(upper_text)

# %%
'Umairmushtaq0345.uma@gmail.com'.split("@")

# %%
"       Umair Mushtaq   ".strip()

# %%
"       Umair Mushtaq   ".rstrip()

# %%
"       Umair Mushtaq   ".lstrip()

# %%
text.replace("python","java")

# %%
print("Hello {}, your balance is {}".format("Adam",230.254))

# %%
name = "Adam"
balance = 230.254

print(f"Hello {name}, your balance is {balance}")

# %%
print(f"Hello {name}, your balance is {balance:.2f}")
