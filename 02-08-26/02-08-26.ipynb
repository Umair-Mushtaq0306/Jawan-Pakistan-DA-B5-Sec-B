# %%
# for cmd type pip install pandas

# %%
# !pip install pandas

# %%
dir(pandas)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 dir(pandas)
#
# NameError: name 'pandas' is not defined

# %%
pd = pandas.read_csv('retail supermarket.csv')
pd
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 pd = pandas.read_csv('retail supermarket.csv')
#       2 pd
#
# NameError: name 'pandas' is not defined

# %%
pd.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 pd.shape
#
# NameError: name 'pd' is not defined

# %%
pd.shape[0]

# %%
pd['Country']

# %%
pd[['Ship Mode','Country','Sales']]

# %%
pd.Sales

# %%
pd.head(10)

# %%
pd.tail(10)

# %%
print(type(pd['Region']))
