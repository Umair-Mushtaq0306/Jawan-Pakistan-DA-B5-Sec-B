# %%
x= 25
y= 45

# %%
print(x+y)
# Out:
# 70

# %% [markdown]
# # LIST

# %%
salaries = ["20k","40k","50K"]

# %%
salaries
# Out:
# ['20k', '40k', '50K']

# %% [markdown]
# ## Indexing

# %%
salaries [0]
# Out:
# '20k'

# %%
len(salaries)
# Out:
# 3

# %%
salaries[-1]
# Out:
# '50K'

# %%
bio = ['umair',45,salaries]
bio
# Out:
# ['umair', 45, ['20k', '40k', '50K']]

# %%
len(bio)
# Out:
# 3

# %%
bio[1]
# Out:
# 45

# %%
bio[2][1]
# Out:
# '40k'

# %% [markdown]
# ## Silicing

# %%
salaries[0:2]
# Out:
# ['20k', '40k']

# %%
salaries[-3:-1]
# Out:
# ['20k', '40k']

# %%
salaries[-3:]
# Out:
# ['20k', '40k', '50K']

# %%
salaries[0:]
# Out:
# ['20k', '40k', '50K']

# %%
salaries[0:3:2]
# Out:
# ['20k', '50K']

# %%
type(salaries)
# Out:
# list

# %%
dir()
# Out:
# ['In',
#  'Out',
#  '_',
#  '_11',
#  '_12',
#  '_13',
#  '_14',
#  '_15',
#  '_16',
#  '_18',
#  '_19',
#  '_21',
#  '_23',
#  '_25',
#  '_26',
#  '_27',
#  '_28',
#  '_29',
#  '_30',
#  '_31',
#  '_32',
#  '_33',
#  '_34',
#  '_35',
#  '_36',
#  '_37',
#  '_38',
#  '_39',
#  '_4',
#  '_40',
#  '_41',
#  '_42',
#  '_43',
#  '_44',
#  '_45',
#  '_46',
#  '_47',
#  '_48',
#  '_49',
#  '_50',
#  '_51',
#  '_52',
#  '_6',
#  '_9',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__session__',
#  '__spec__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_i10',
#  '_i11',
#  '_i12',
#  '_i13',
#  '_i14',
#  '_i15',
#  '_i16',
#  '_i17',
#  '_i18',
#  '_i19',
#  '_i2',
#  '_i20',
#  '_i21',
#  '_i22',
#  '_i23',
#  '_i24',
#  '_i25',
#  '_i26',
#  '_i27',
#  '_i28',
#  '_i29',
#  '_i3',
#  '_i30',
#  '_i31',
#  '_i32',
#  '_i33',
#  '_i34',
#  '_i35',
#  '_i36',
#  '_i37',
#  '_i38',
#  '_i39',
#  '_i4',
#  '_i40',
#  '_i41',
# ...

# %%
salaries.index('20k')
# Out:
# 0
