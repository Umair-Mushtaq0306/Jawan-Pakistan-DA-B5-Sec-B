# %%
x= 25
y= 45

# %%
print(x+y)
# Out:
# 70

# %% [markdown]
# # LIST

# %%
salaries = ["20k","40k","50K"]

# %%
salaries
# Out:
# ['20k', '40k', '50K']

# %% [markdown]
# ## Indexing

# %%
salaries [0]
# Out:
# '20k'

# %%
len(salaries)
# Out:
# 3

# %%
salaries[-1]
# Out:
# '50K'

# %%
bio = ['umair',45,salaries]
bio
# Out:
# ['umair', 45, ['20k', '40k', '50K']]

# %%
len(bio)
# Out:
# 3

# %%
bio[1]
# Out:
# 45

# %%
bio[2][1]
# Out:
# '40k'
