# %% [markdown]
# ## Error Handling

# %%
print(1/0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print(1/0)
#
# ZeroDivisionError: division by zero

# %%
print(1/'a')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 print(1/'a')
#
# TypeError: unsupported operand type(s) for /: 'int' and 'str'

# %%
int('abc')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 int('abc')
#
# ValueError: invalid literal for int() with base 10: 'abc'

# %%
print(3*5)
print(1/0)
print(4+3)
# Out:
# 15
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[4], line 2
#       1 print(3*5)
# ----> 2 print(1/0)
#       3 print(4+3)
#
# ZeroDivisionError: division by zero

# %%
print(3*5)

try:
    print(1/0)


print(4+3)
# Out:
#   Cell In[5], line 7
#     print(4+3)
#     ^
# SyntaxError: expected 'except' or 'finally' block

# %%
print(3*5)

try:
    print(1/0)
except ZeroDivisionError:
    print('can not divided by zero')

print(4+3)
# Out:
# 15
# can not divided by zero
# 7

# %%
print(3*5)

try:
    print(1/'a')
except TypeError:
    print('can not divided by string')

print(4+3)
# Out:
# 15
# can not divided by string
# 7

# %%
print(3*5)

try:
    print(1/'a')
except :
    print('can not divided by string')

print(4+3)
# Out:
# 15
# can not divided by string
# 7

# %%
try:
    num1 = int(input('Enter Num1: '))
    num2 = int(input('Enter Num2: '))
    result = num1/num2

except TypeError:
    print("Error")
except ZeroDivisionError:
    print('can not divide by zero')

except ValueError:
    print('Value Error')
# Out:
# Enter Num1:  2
# Enter Num2:  0
# can not divide by zero

# %%
try:
    num1 = int(input('Enter Num1: '))
    num2 = int(input('Enter Num2: '))
    result = num1/num2

except TypeError:
    print("Error")
except ZeroDivisionError:
    print('can not divide by zero')

except ValueError:
    print('Value Error')
# Out:
# Enter Num1:  2
# Enter Num2:  a
# Value Error

# %%
try:
    num1 = int(input('Enter Num1: '))
    num2 = int(input('Enter Num2: '))
    result = num1/num2

except TypeError:
    print("Error")
except ZeroDivisionError:
    print('can not divide by zero')

except ValueError:
    print('Value Error')
# Out:
# Enter Num1:  10
# Enter Num2:  2

# %%
try:
    num1 = int(input('Enter Num1: '))
    num2 = int(input('Enter Num2: '))
    result = num1/num2

except TypeError:
    print("Error")
except ZeroDivisionError:
    print('can not divide by zero')

except ValueError:
    print('Value Error')
else:
    print(result)
# Out:
# Enter Num1:  10
# Enter Num2:  2
# 5.0

# %%
try:
    num1 = int(input('Enter Num1: '))
    num2 = int(input('Enter Num2: '))
    result = num1/num2

except TypeError:
    print("Error")
except ZeroDivisionError:
    print('can not divide by zero')

except ValueError:
    print('Value Error')
else:
    print(result)

finally:
    print('Program Executed')
# Out:
# Enter Num1:  2
# Enter Num2:  0
# can not divide by zero
# Program Executed

# %%
try:
    num1 = int(input('Enter Num1: '))
    num2 = int(input('Enter Num2: '))
    result = num1/num2

except TypeError:
    print("Error")
except ZeroDivisionError:
    print('can not divide by zero')

except ValueError:
    print('Value Error')
else:
    print(result)

finally:
    print('Program Executed')
# Out:
# Enter Num1:  10
# Enter Num2:  5
# 2.0
# Program Executed

# %%
try:
    num1 = int(input('Enter Num1: '))
    num2 = int(input('Enter Num2: '))
    result = num1/num2

except :
    print("Error")
else:
    print(result)

finally:
    print('Program Executed')
# Out:
# Enter Num1:  2
# Enter Num2:  a
# Error
# Program Executed

# %%
try:
    num1 = int(input('Enter Num1: '))
    num2 = int(input('Enter Num2: '))
    result = num1/num2

except ZeroDivisionError:
    print('can not divide by zero')
except :
    print("Error")
else:
    print(result)

finally:
    print('Program Executed')
# Out:
# Enter Num1:  2
# Enter Num2:  0
# can not divide by zero
# Program Executed

# %%
# Basic exception handling
try:
    number = int(input("Enter a number: "))
    result = 10 / number
    print(f"Result: {result}")
except ValueError:
    print("Please enter a valid number!")
except ZeroDivisionError:
    print("Cannot divide by zero!")
# Out:
# Enter a number:  umair
# Please enter a valid number!

# %%
# Handling multiple exceptions
try:
    numbers = [1, 2, 3]
    index = int(input("Enter index: "))
    value = numbers[index]
    result = 100 / value
    print(result)
except (ValueError, IndexError, ZeroDivisionError) as e:
    print(f"Error occurred: {e}")
# Out:
# Enter index:  4
# Error occurred: list index out of range

# %%
data = ['10','20','30','abc']
for value in data:
    try:
        number = int(value)
    except ValueError:
        print(f'Invalid value found: {value}')
    else:
        print(f'valid number: {number}')
    finally:
        print('Checked one value\n')
# Out:
# valid number: 10
# Checked one value
#
# valid number: 20
# Checked one value
#
# valid number: 30
# Checked one value
#
# Invalid value found: abc
# Checked one value

# %% [markdown]
# ## Object Oriented Programming (OOP)

# %%
print(type('ab'))
# Out:
# <class 'str'>

# %%
print(type([1,1,2]))
# Out:
# <class 'list'>

# %%
class Student:
    def greet():
        return 'Welcome'

# %%
stud = Student()
stud

# %%
stud.greet()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 stud.greet()
#
# TypeError: Student.greet() takes 0 positional arguments but 1 was given

# %%
class Student:
    def greet(self):
        return 'Welcome'

# %%
stud = Student()

# %%
stud.greet()
# Out:
# 'Welcome'

# %%
class Student:
    def greet(self): #self is object
        print(f'object : {self}')
        return 'Welcome'

# %%
stud = Student()

# %%
stud.greet()
# Out:
# object : <__main__.Student object at 0x0000016D6BFF60D0>
# 'Welcome'

# %%
class Student:
    def greet(self,name,age):
        self.stu_name = name # 1 atribute
        self.stu_age = age   # 2 atribute
        return 'Welcome'

# %%
stud = Student()
stud

# %%
stud.greet('Umair',28)
# Out:
# 'Welcome'

# %%
stud.stu_name
# Out:
# 'Umair'

# %%
stud.stu_age
# Out:
# 28

# %%
print(stud.greet('Umair',28))
print(stud.stu_name)
print(stud.stu_age)
# Out:
# Welcome
# Umair
# 28

# %%
def sub():
    return 'Learning OOP' #print and terminate
    print('Hello')

# %%
sub()
# Out:
# 'Learning OOP'

# %%
def sub():
    print('Hello')
    return 'Learning OOP' #print and terminate

# %%
sub()
# Out:
# Hello
# 'Learning OOP'

# %%
class Student:
    def greet(self,name,age):
        self.stu_name = name # 1 atribute
        self.stu_age = age   # 2 atribute
        return 'Welcome'

    def sub(self):
        return 'Learning OOPs'

# %%
stud = Student()
stud

# %%
stud.sub()
# Out:
# 'Learning OOPs'

# %%
stud.greet('Umair Mushtaq',28)
# Out:
# 'Welcome'

# %%
stud.stu_name
# Out:
# 'Umair Mushtaq'

# %%
stud.stu_age
# Out:
# 28

# %%
# Constructor

# %%
class Student:
    def __init__(self,school_name,location,Class):
        self.school = school_name
        self.location = location
        return 'hello'
    def greet(self,name,age):
        self.stu_name = name # 1 atribute
        self.stu_age = age   # 2 atribute
        return 'Welcome'

    def sub(self):
        return 'Learning OOPs'

# %%
stud = Student(school_name='Karachi City',location='Karachi',Class='10th')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 stud = Student(school_name='Karachi City',location='Karachi',Class='10th')
#
# TypeError: __init__() should return None, not 'str'

# %%
class Student:
    def __init__(self,school_name,location,Class):
        self.school = school_name
        self.location = location
        print('hello')
    def greet(self,name,age):
        self.stu_name = name # 1 atribute
        self.stu_age = age   # 2 atribute
        return 'Welcome'

    def sub(self):
        return 'Learning OOPs'

# %%
Student(school_name='Karachi City',location='Karachi',Class='10th')
# Out:
# hello

# %%
stud = Student('Karachi City','Karachi','10th')
stud
# Out:
# hello

# %%
print(stud.school)
print(stud.location)
# Out:
# Karachi City
# Karachi

# %%
class Student:
    def __init__(self,school_name,location,Class):
        self.name = school_name
    def greet(self,name,age):
        self.name = name # 1 atribute
      

    def sub(self):
        return 'Learning OOPs'

# %%
stud = Student('Karachi City','Karachi','10th')
stud

# %%
stud.name
# Out:
# 'Karachi City'

# %%
stud.greet('Umair',28)

# %%
stud.name
# Out:
# 'Umair'
