# %%
"open"
# Out:
# 'open'

# %%
2+3 # add
# Out:
# 5

# %%
print (2+3)
# Out:
# 5

# %%
2-3 # sub
# Out:
# -1

# %%
3*3 # mul
# Out:
# 9

# %%
3**5 # power
# Out:
# 243

# %%
3**5 # 3*3*3*3*3
# Out:
# 243

# %%
3**5 #3*3
# Out:
# 243

# %%
print (2-3)
# Out:
# -1

# %%
10/2
# Out:
# 5.0

# %%
10//2
# Out:
# 5

# %%
10//2 # int div # floor Devision
# Out:
# 5

# %%
10%4
# Out:
# 2

# %%
10%2
# Out:
# 0

# %% [markdown]
# name = "umair"

# %%
x = 5000

# %%
x= x+5000

# %%
x
# Out:
# 10000

# %%
name="umair"

# %%
name
# Out:
# 'umair'

# %%
emp=40000

# %%
emp=40000+4000

# %%
emp
# Out:
# 44000

# %%
name="Mr." + name

# %%
name
# Out:
# 'Mr.umair'

# %%
emp
# Out:
# 44000

# %%
emp=emp+4500

# %%
emp
# Out:
# 48500

# %%
"123"+"45"
# Out:
# '12345'

# %%
"Umair" + " Mushtaq"
# Out:
# 'Umair Mushtaq'

# %%
"Umair" + " " + "Mushtaq"
# Out:
# 'Umair Mushtaq'

# %%
type("Umair")
# Out:
# str

# %%
type(123)
# Out:
# int

# %%
type(123.12)
# Out:
# float

# %% [markdown]
# # HELLO WORLD H1

# %% [markdown]
# ## HELLO WORLD H2

# %% [markdown]
# ### HELLO H3

# %% [markdown]
# #### H4

# %% [markdown]
# ###### H6

# %% [markdown]
# ##### H5

# %%
x = 5
y = 4
z = 7

# %%
x
y
z
# Out:
# 7

# %%
print(x,y,z)
# Out:
# 5 4 7

# %%
print(x)
print(y)
print(z)
# Out:
# 5
# 4
# 7

# %%
"sara's house"
# Out:
# "sara's house"

# %%
'sara\'s house'
# Out:
# "sara's house"

# %%
we are learnin
python
# Out:
#   Cell In[25], line 1
#     we are learnin
#        ^
# SyntaxError: invalid syntax

# %%
'''we are learnin
python'''
# Out:
# 'we are learnin\npython'

# %%
print('''we are learning
python''')
# Out:
# we are learning
# python

# %%
print("""we are learning
python""")
# Out:
# we are learning
# python

# %%
c = '456'
type(c)
# Out:
# str

# %%
int(c)
# Out:
# 456

# %%
c
# Out:
# '456'

# %%
int(453.12)
# Out:
# 453

# %%
float("456.6")
# Out:
# 456.6

# %%
float(456)
# Out:
# 456.0

# %%
float("456")
# Out:
# 456.0

# %%
str(456)
# Out:
# '456'

# %%
str(123)
# Out:
# '123'

# %%
type(2j)
# Out:
# complex
